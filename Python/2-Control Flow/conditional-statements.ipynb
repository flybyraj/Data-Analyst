# %%
## If statement

age=20

if age>=18:
    print("Allowed to vote in election")
# Out:
# Allowed to vote in election

# %%
age>=18
# Out:
# True

# %%
##Else
##else statement executeq a block of code if the condition in the if statement is False.

age=16

if age>=18:
    print("Eligible for Voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
##Elif
##elif statement allows you to check multiple conditions . it stands for Else-If

age=17

if age<13:
    print("you are a Child")
elif age<18:
    print("Ypu are a teenager")
else:
    print("Yoou are an adult")
# Out:
# Ypu are a teenager

# %%
##Nested conditional Statements

##you can place one or more if , elif or else statements inside another if , elif or else statement

##number even , odd , negative

num=int(input("Enter the number: "))

if num>=0:
    print("The number is positive")
    if num%2==0:
        print("The number is Even")
    else:
        print("The number is Odd")
else:
    print("The number is zero or Negative")
# Out:
# The number is positive
# The number is Odd

# %%
##Practical Exammples
## Determine if a year is a leap year using nested condition statement

year=int(input("Enter the year"))

if year%4==0:
    if year%100==0:
        print("Leap Year")
elif year%400==0:
    print("Leap Year")
else:
    print("Not a leap Year")
# Out:
# Leap Year

# %%
## Assignment
## SImple Calculator program

#take input
num1=float(input("Enter First NUmber: "))
num2=float(input("Enter Second Number: "))
operation=input("Enter the Operation (+,-,/,*,%): ")

#perform requested operation
if operation == '+':
    result=num1+num2
elif operation == '-':
    result=num1-num2
elif operation == '*':
    result=num1*num2
elif operation == '/':
    if num2 !=0:
        result=num1/num2
    else:
        result="Error! Division by Zero."
elif operation == '%':
    result=num1%num2
else:
    result="Invalid Operation"


print("result: ",result)
# Out:
# result:  10.0

# %%
##Determine the ticket price based on age and weather the person is a student.
# Ticket pricing based on age and student status

age=int(input("Enter the age : "))
is_student = input("Are you Student? (yes/no): ").lower()

## TIcket price
if age<5:
    price="Free"
elif age <=12:
    price="$10"
elif age<= 17:
    if is_student == 'yes':
        price="$12"
    else:
        price="$15"
elif age<=64:
    if is_student == 'yes':
        price = "$18"
    else:
        price="$25"
else:
    price="$20"
