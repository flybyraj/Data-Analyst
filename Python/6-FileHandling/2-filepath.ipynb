# %%
## Creating a new directory

import os

new_directory="package"
os.mkdir(new_directory)
print(f"Directory'{new_directory}' create ")
# Out:
# Directory'package' create

# %%
## Listing file and Directories

items=os.listdir('.')
print(items)
# Out:
# ['1-FileOperation.ipynb', '2-filepath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'package']

# %%
## Joining Paths

dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
path='example.txt'
if os.path.exists(path):
    print((f"THe path '{path}' exists"))
else:
    print(f"The Path '{path}' does not exists")
# Out:
# THe path 'example.txt' exists

# %%
# Checking if a Path is a File or Directory

import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a direcotry.")
else:
    print(f"The path '{path}' is neither a file nor a direcotry.")
# Out:
# The path 'example.txt' is a file.

# %%
## Getting the absolute Path.

relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\669ra\Desktop\Data-Analyst\Python\6-FileHandling\example.txt
