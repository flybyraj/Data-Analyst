# %% [markdown]
# Function Examples
#
# Example 1: Temprature Conversion

# %%
def conv_temp(temp,unit):
    """This function converts temprature bw Celcius and Fahrenheit"""
    if unit=='C':
        return temp* 9/5 + 32 ## Celcuis to Fahrenheit
    elif unit=='F':
        return (temp-32)*5/9 ## F to C
    else:
        return None

print(conv_temp(25,'C'))
print(conv_temp(77,'F'))
# Out:
# 77.0
# 25.0

# %% [markdown]
# Example 2: Password Strength Checker

# %%
def strenght_check(password):
    """This function checks if password is strong or not"""
    if len(password)<8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
        return False
    return True

## Calling Function
print(strenght_check("Weakpass@1"))
# Out:
# True

# %% [markdown]
# Example 3: Calculate the Total Cost of Items in a Shopping Cart

# %%
def calculate_cost(cart):
    total_cost=0
    for item in cart:
        total_cost+=item['price']* item['quantity']
    return total_cost


## Example cart data

cart=[
    {'name':'Apple','price':0.5,'quantity':4},
    {'name':'Banana','price':0.3,'quantity':6},
    {'name':'Orange','price':0.7,'quantity':3}
]

total_cost=calculate_cost(cart)
print(total_cost)
# Out:
# 5.8999999999999995

# %% [markdown]
# Example 4: Check if a String is Palindrome

# %%
def is_palindrome(s):
    s=s.lower().replace(" ","")
    return s==s[::-1]

print(is_palindrome("  Rar"))
print(is_palindrome("hello"))
# Out:
# True
# False

# %% [markdown]
# Example 5: Calculate factorial of a number using recursion

# %%
def factorial(n):
    if n==0:
        return 1
    else:
        return n* factorial(n-1)
    
print(factorial(4))
# Out:
# 24

# %% [markdown]
# Example 7: Validate Email Address

# %%
import re

def is_valid(email):
    pattern = r'^[a-zA-Z0-9_.+-]+@[a-zA-z0-9-]+\.[a-zA-Z0-9-.]+$'
    return re.match(pattern , email)is not None

print(is_valid("669raj@gmail.com"))
print(is_valid("invalid.com"))
# Out:
# True
# False
