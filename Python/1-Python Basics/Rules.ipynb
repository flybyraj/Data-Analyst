# %%
##Single Line Comment
'''
Multi Line Comment
'''
# Out:
# '\nMulti Line Comment\n'

# %%
##Python is case sensitive

name="Raj"
Name="Sharma"
print(name)
print(Name)
# Out:
# Raj
# Sharma

# %%
##Indentation
##Python uses indentation to define blocs of code
##consistent use of space(4) or Tab is required
##Python uses indentation to determine grouping of statements

age=32
if(age>30):
    print(age)

print("Hellow")
# Out:
# 32
# Hellow

# %%
##Line Continuation
##use a backslash(\) to continue a statement to next line
 
total=1+2+3\
+4+5
print(total)
# Out:
# 15

# %%
##Multiple statements in Single Line(;)

x=5;y=6;z=x+y;
print(z)
# Out:
# 11
