# %%
## Arithmetic Operations 

a=10
b=5

add_result=a+b
sub_result=a-b
mult_result=a*b
div_result=a/b
floor_div_result=a//b
modulus_result=a%b
exponential_result=a**b

print(add_result)
print(sub_result)
print(mult_result)
print(div_result)
print(floor_div_result) ##Lowest Integer Value
print(modulus_result)
print(exponential_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %% [markdown]
# ### Comparision Operators

# %%
## ==Equal to
a=10
b=10

a==b
# Out:
# True

# %%
str1="Raj"
str2="Raj"
str1==str2
# Out:
# True

# %%
## Not Equal to !=
str!=str2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## Not Equal to !=
# ----> 2 str!=str2
#
# NameError: name 'str2' is not defined

# %%
str3="raj"
str4="Raj"

str3!=str4
# Out:
# True

# %%
## Greater Than> ##Less Than<

num1=45
num2=55

print(num1>num2) ##Flase
print(num1<num2) ##True Boolean Value
# Out:
# False
# True

# %%
##greater than or Equal>= to or Less than Equal to<=

number1=45
number2=45

print(number1>= number2)
print(number1<= number2)
# Out:
# True
# True

# %% [markdown]
# Logical operators

# %%
## And Or Not

##AND
X=False ; Y=True

result=X and Y
print(result)
# Out:
# False

# %%
##OR

X=False
Y=False

result= X or Y
print(result)
# Out:
# False

# %%
## NOT

X=True
result=not X
print(result)
# Out:
# False
