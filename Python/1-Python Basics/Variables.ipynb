# %% [markdown]
# Variables
# variable is declared automatically automatically when you assign a value

# %%
a=100

# %%
##Declaring and Assigning Variables

age=22
height=5.11
name="Raj"
is_student=True

##Printing the variables

print("Age :",age)
print("Height :",height)
print("Name :",name)
print("Is Student", is_student)
# Out:
# Age : 22
# Height : 5.11
# Name : Raj
# Is Student True

# %%
##Naming Conventions
##Variable name should be descriptive
##must start with a letter or '_' and contains letter,numbers and underscores
##variables names case sensitive

##valid variable names

first_name="Raj"
last_name="sharma"

# %%
##Invalid variables names

#2age=30
#first-name="Raj"
#@name="Raj"
# Out:
#   Cell In[7], line 5
#     @name="Raj"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
##Case Sensitivity
name="Raj"
Name="Sharma"

print(name)
print(Name)
name==Name
# Out:
# Raj
# Sharma
# False

# %%
##understanding Variable Types
##Python is dynamically typed , type of variable is determined at runtime

age=22 #int
height=5.11 #float
name="Raj" #str
is_student=True #boolean

print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
##Type checking and Conversion

type(height)
# Out:
# float

# %%
age=25
print(type(age))

#Type Conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25' #String
int(age)
print(type(int(age)))
type(age)
# Out:
# <class 'int'>
# str

# %%
name="Raj"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 name="Raj"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'Raj'

# %%
height=5.11
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 5

# %%
float(int(height))
# Out:
# 5.0

# %%
## Dynamic Typing
##Python allows the type of a veriable to change as the program executes

var=10  #int
print(var,type(var))

var="Hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
##Input

age=int(input("what is the age"))
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
##Simple Calculator
num1 = float(input("Enter First Number: "))
num2 = float(input("Enter Second Number: "))

sum =num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum: ", sum)
print("Difference: ", difference)
print("Product: ", product)
print("Quotient: " , quotient)
# Out:
# Sum:  30.0
# Difference:  10.0
# Product:  200.0
# Quotient:  2.0
