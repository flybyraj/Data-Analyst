# %%
##Understand Semantics in Python
#Variable Assignment
age=32 ##age is a number
name="raj" ##Name is a String
# Out:
# int

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
##Type Interference
variable=10
print(type(variable))
variable="raj"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
##Indentation Error
age=32
if (age>30):
print(age)
# Out:
#   Cell In[11], line 4
#     print(age)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
##Name Error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 ##Name Error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
##Example of Indentation
if True:
    print("Corerect Indentation")
    if False:
        print("This wont Print")
    print("this will Print")
print("This is outside If block")
# Out:
# Corerect Indentation
# this will Print
# This is outside If block
